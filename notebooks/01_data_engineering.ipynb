# %% [markdown]
# # 1. Problem Overview
# Prepare and engineer structured features from multiple relational datasets
# to build a classification model that predicts whether a film
# will have a high rating (≥ 7).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
import os
os.getcwd()
# Out:
# '/home/utsb/.app/Code/movie-rating-prediction/notebooks'

# %% [markdown]
# ## 2. Data Loading

# %%
films = pd.read_csv("../data/raw/films.csv")
reviews = pd.read_csv("../data/raw/reviews.csv")
people = pd.read_csv("../data/raw/people.csv")
roles = pd.read_csv("../data/raw/roles.csv")

print("Films:", films.shape)
print("Reviews:", reviews.shape)
print("People:", people.shape)
print("Roles:", roles.shape)
# Out:
# Films: (4967, 9)
# Reviews: (4967, 6)
# People: (8396, 4)
# Roles: (19790, 4)

# %%
films.head()
# Out:
#    1 Intolerance: Love's Struggle Throughout the Ages  1916.0      USA  123.0  \
# 0  2                   Over the Hill to the Poorhouse  1920.0      USA  110.0
# 1  3                                   The Big Parade  1925.0      USA  151.0
# 2  4                                       Metropolis  1927.0  Germany  145.0
# 3  5                                    Pandora's Box  1929.0  Germany  110.0
# 4  6                              The Broadway Melody  1929.0      USA  100.0
#
#   Unnamed: 5  Not Rated  Unnamed: 7   385907.0
# 0        NaN        NaN   3000000.0   100000.0
# 1        NaN  Not Rated         NaN   245000.0
# 2     German  Not Rated     26435.0  6000000.0
# 3     German  Not Rated      9950.0        NaN
# 4    English     Passed   2808000.0   379000.0

# %%
films.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4967 entries, 0 to 4966
# Data columns (total 9 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   1                                                 4967 non-null   int64
#  1   Intolerance: Love's Struggle Throughout the Ages  4967 non-null   str
#  2   1916.0                                            4925 non-null   float64
#  3   USA                                               4965 non-null   str
#  4   123.0                                             4954 non-null   float64
#  5   Unnamed: 5                                        4955 non-null   str
#  6   Not Rated                                         4665 non-null   str
#  7   Unnamed: 7                                        4158 non-null   float64
#  8   385907.0                                          4537 non-null   float64
# dtypes: float64(4), int64(1), str(4)
# memory usage: 349.4 KB

# %% [markdown]
# ## 3. Data Cleaning
# - Fixed malformed CSV headers
# - Handled missing numeric values
# - Converted datatypes

# %%
films.columns
reviews.columns
roles.columns
people.columns
# Out:
# Index(['1', '50 Cent', '1975-07-06', 'Unnamed: 3'], dtype='str')

# %%
films = pd.read_csv("../data/raw/films.csv", header=None)
films.head()
# Out:
#    0                                                 1       2        3  \
# 0  1  Intolerance: Love's Struggle Throughout the Ages  1916.0      USA
# 1  2                    Over the Hill to the Poorhouse  1920.0      USA
# 2  3                                    The Big Parade  1925.0      USA
# 3  4                                        Metropolis  1927.0  Germany
# 4  5                                     Pandora's Box  1929.0  Germany
#
#        4       5          6          7          8
# 0  123.0     NaN  Not Rated        NaN   385907.0
# 1  110.0     NaN        NaN  3000000.0   100000.0
# 2  151.0     NaN  Not Rated        NaN   245000.0
# 3  145.0  German  Not Rated    26435.0  6000000.0
# 4  110.0  German  Not Rated     9950.0        NaN

# %%
films.columns
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
films.columns = [
    "id",
    "title",
    "year",
    "country",
    "runtime",
    "language",
    "certificate",
    "budget",
    "revenue"
]

# %%
films.head()
films.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4968 entries, 0 to 4967
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4968 non-null   int64
#  1   title        4968 non-null   str
#  2   year         4926 non-null   float64
#  3   country      4966 non-null   str
#  4   runtime      4955 non-null   float64
#  5   language     4955 non-null   str
#  6   certificate  4666 non-null   str
#  7   budget       4158 non-null   float64
#  8   revenue      4538 non-null   float64
# dtypes: float64(4), int64(1), str(4)
# memory usage: 349.4 KB

# %%
films.isnull().sum()
# Out:
# id               0
# title            0
# year            42
# country          2
# runtime         13
# language        13
# certificate    302
# budget         810
# revenue        430
# dtype: int64

# %%
films["year"] = films["year"].fillna(films["year"].median())

# %%
films["year"] = films["year"].fillna(films["year"].median())

# %%
films["budget"] = films["budget"].fillna(0)
films["revenue"] = films["revenue"].fillna(0)

# %%
films["year"] = films["year"].astype(int)
films["runtime"] = films["runtime"].astype(int)
# Out:
#   Cell In[18], line 1
#     year float64
#          ^
# SyntaxError: invalid syntax

# %%
films["year"] = films["year"].astype(int)
films["runtime"] = films["runtime"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[80], line 2
#       1 films["year"] = films["year"].astype(int)
# ----> 2 films["runtime"] = films["runtime"].astype(int)
#
# File ~/.app/Python-Venv/venv/lib64/python3.14/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File ~/.app/Python-Venv/venv/lib64/python3.14/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File ~/.app/Python-Venv/venv/lib64/python3.14/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~/.app/Python-Venv/venv/lib64/python3.14/site-packages/pandas/core/internals/blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File ~/.app/Python-Venv/venv/lib64/python3.14/site-packages/pandas/core/dtypes/astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File ~/.app/Python-Venv/venv/lib64/python3.14/site-packages/pandas/core/dtypes/astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/.app/Python-Venv/venv/lib64/python3.14/site-packages/pandas/core/dtypes/astype.py:102, in _astype_nansafe(arr, dtype, copy, skipna)
#      97     return lib.ensure_string_array(
#      98         arr, skipna=skipna, convert_na_value=False
#      99     ).reshape(shape)
#     101 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 102     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     104 elif arr.dtype == object:
#     105     # if we have a datetime/timedelta array of objects
#     106     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     108     if lib.is_np_dtype(dtype, "M"):
#
# File ~/.app/Python-Venv/venv/lib64/python3.14/site-packages/pandas/core/dtypes/astype.py:146, in _astype_float_to_int_nansafe(values, dtype, copy)
#     142 """
#     143 astype with a check preventing converting NaN to a meaningless integer value.
#     144 """
#     145 if not np.isfinite(values).all():
# --> 146     raise IntCastingNaNError(
#     147         "Cannot convert non-finite values (NA or inf) to integer."
#     148         "Replace or remove non-finite values or cast to an integer type"
#     149         "that supports these values (e.g. 'Int64')"
#     150     )
#     151 if dtype.kind == "u":
#     152     # GH#45151
#     153     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer.Replace or remove non-finite values or cast to an integer typethat supports these values (e.g. 'Int64')

# %%
films["runtime"].isnull().sum()
films["year"].isnull().sum()
# Out:
# np.int64(0)

# %%
films["year"] = films["year"].fillna(films["year"].median())
films["runtime"] = films["runtime"].fillna(films["runtime"].median())

# %%
films["year"] = films["year"].astype(int)
films["runtime"] = films["runtime"].astype(int)

# %%
films.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4968 entries, 0 to 4967
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4968 non-null   int64
#  1   title        4968 non-null   str
#  2   year         4968 non-null   int64
#  3   country      4966 non-null   str
#  4   runtime      4968 non-null   int64
#  5   language     4955 non-null   str
#  6   certificate  4666 non-null   str
#  7   budget       4968 non-null   float64
#  8   revenue      4968 non-null   float64
# dtypes: float64(2), int64(3), str(4)
# memory usage: 349.4 KB

# %%
reviews.head()
reviews.info()
reviews.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4967 entries, 0 to 4966
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   3934       4967 non-null   int64
#  1   588.0      4948 non-null   float64
#  2   432.0      4921 non-null   float64
#  3   7.0999999  4967 non-null   float64
#  4   203461     4967 non-null   int64
#  5   46000      4967 non-null   int64
# dtypes: float64(3), int64(3)
# memory usage: 233.0 KB
# Index(['3934', '588.0', '432.0', '7.0999999', '203461', '46000'], dtype='str')

# %%
reviews = pd.read_csv("../data/raw/reviews.csv", header=None)
reviews.head()
# Out:
#       0       1      2    3       4      5
# 0  3934   588.0  432.0  7.1  203461  46000
# 1  3405   285.0  267.0  6.4  149998      0
# 2   478    65.0   29.0  3.2    8465    491
# 3    74    83.0   25.0  7.6    7071    930
# 4  1254  1437.0  224.0  8.0  241030  13000

# %%
reviews.columns = [
    "film_id",
    "metric_1",
    "metric_2",
    "avg_rating",
    "vote_count",
    "metric_3"
]

reviews.head()
# Out:
#    film_id  metric_1  metric_2  avg_rating  vote_count  metric_3
# 0     3934     588.0     432.0         7.1      203461     46000
# 1     3405     285.0     267.0         6.4      149998         0
# 2      478      65.0      29.0         3.2        8465       491
# 3       74      83.0      25.0         7.6        7071       930
# 4     1254    1437.0     224.0         8.0      241030     13000

# %% [markdown]
# ## 4. Feature Engineering
#
# ### Review Merge
# - Merged rating and vote count data from the reviews dataset
# - Linked using film ID
#
# ### Cast Size Extraction
# - Filtered actors from roles dataset
# - Counted number of actors per film
# - Merged cast size into films dataset
#
# ### Target Creation
# - Created binary classification label:
#   - 1 → avg_rating ≥ 7 (High Rated)
#   - 0 → avg_rating < 7 (Low Rated)

# %%
films = films.merge(
    reviews[["film_id", "avg_rating", "vote_count"]],
    left_on="id",
    right_on="film_id",
    how="left"
)

films.head()
# Out:
#    id                                             title  year  country  \
# 0   1  Intolerance: Love's Struggle Throughout the Ages  1916      USA
# 1   2                    Over the Hill to the Poorhouse  1920      USA
# 2   3                                    The Big Parade  1925      USA
# 3   4                                        Metropolis  1927  Germany
# 4   5                                     Pandora's Box  1929  Germany
#
#    runtime language certificate     budget    revenue  film_id  avg_rating  \
# 0      123      NaN   Not Rated        0.0   385907.0        1         8.0
# 1      110      NaN         NaN  3000000.0   100000.0        2         4.8
# 2      151      NaN   Not Rated        0.0   245000.0        3         8.3
# 3      145   German   Not Rated    26435.0  6000000.0        4         8.3
# 4      110   German   Not Rated     9950.0        0.0        5         8.0
#
#    vote_count
# 0       10718
# 1           5
# 2        4849
# 3      111841
# 4        7431

# %%
films[["id", "avg_rating", "vote_count"]].head()
films["avg_rating"].isnull().sum()
# Out:
# np.int64(0)

# %%
films["target"] = (films["avg_rating"] >= 7).astype(int)

# %%
films["target"].value_counts()
# Out:
# target
# 0    3250
# 1    1718
# Name: count, dtype: int64

# %%
roles = pd.read_csv("../data/raw/roles.csv", header=None)
roles.head()
roles.shape
# Out:
# (19791, 4)

# %%
roles.head()
# Out:
#    0  1     2         3
# 0  1  1  1630  director
# 1  2  1  4843     actor
# 2  3  1  5050     actor
# 3  4  1  8175     actor
# 4  5  2  3000  director

# %%
roles.columns = ["role_id", "film_id", "person_id", "role_type"]
roles.head()
# Out:
#    role_id  film_id  person_id role_type
# 0        1        1       1630  director
# 1        2        1       4843     actor
# 2        3        1       5050     actor
# 3        4        1       8175     actor
# 4        5        2       3000  director

# %%
actors = roles[roles["role_type"] == "actor"]

# %%
cast_size = (
    actors
    .groupby("film_id")
    .size()
    .reset_index(name="cast_count")
)

cast_size.head()
# Out:
#    film_id  cast_count
# 0        1           3
# 1        2           3
# 2        3           3
# 3        4           3
# 4        5           3

# %%
films = films.merge(
    cast_size,
    left_on="id",
    right_on="film_id",
    how="left"
)

films["cast_count"] = films["cast_count"].fillna(0)

films.head()
# Out:
#    id                                             title  year  country  \
# 0   1  Intolerance: Love's Struggle Throughout the Ages  1916      USA
# 1   2                    Over the Hill to the Poorhouse  1920      USA
# 2   3                                    The Big Parade  1925      USA
# 3   4                                        Metropolis  1927  Germany
# 4   5                                     Pandora's Box  1929  Germany
#
#    runtime language certificate     budget    revenue  film_id_x  avg_rating  \
# 0      123      NaN   Not Rated        0.0   385907.0          1         8.0
# 1      110      NaN         NaN  3000000.0   100000.0          2         4.8
# 2      151      NaN   Not Rated        0.0   245000.0          3         8.3
# 3      145   German   Not Rated    26435.0  6000000.0          4         8.3
# 4      110   German   Not Rated     9950.0        0.0          5         8.0
#
#    vote_count  target  film_id_y  cast_count
# 0       10718       1        1.0         3.0
# 1           5       0        2.0         3.0
# 2        4849       1        3.0         3.0
# 3      111841       1        4.0         3.0
# 4        7431       1        5.0         3.0

# %%
films = films.drop(columns=["film_id_x", "film_id_y"])

# %%
films.head()
# Out:
#    id                                             title  year  country  \
# 0   1  Intolerance: Love's Struggle Throughout the Ages  1916      USA
# 1   2                    Over the Hill to the Poorhouse  1920      USA
# 2   3                                    The Big Parade  1925      USA
# 3   4                                        Metropolis  1927  Germany
# 4   5                                     Pandora's Box  1929  Germany
#
#    runtime language certificate     budget    revenue  avg_rating  vote_count  \
# 0      123      NaN   Not Rated        0.0   385907.0         8.0       10718
# 1      110      NaN         NaN  3000000.0   100000.0         4.8           5
# 2      151      NaN   Not Rated        0.0   245000.0         8.3        4849
# 3      145   German   Not Rated    26435.0  6000000.0         8.3      111841
# 4      110   German   Not Rated     9950.0        0.0         8.0        7431
#
#    target  cast_count
# 0       1         3.0
# 1       0         3.0
# 2       1         3.0
# 3       1         3.0
# 4       1         3.0

# %%
films.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4968 entries, 0 to 4967
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4968 non-null   int64
#  1   title        4968 non-null   str
#  2   year         4968 non-null   int64
#  3   country      4966 non-null   str
#  4   runtime      4968 non-null   int64
#  5   language     4955 non-null   str
#  6   certificate  4666 non-null   str
#  7   budget       4968 non-null   float64
#  8   revenue      4968 non-null   float64
#  9   avg_rating   4968 non-null   float64
#  10  vote_count   4968 non-null   int64
#  11  target       4968 non-null   int64
#  12  cast_count   4968 non-null   float64
# dtypes: float64(4), int64(5), str(4)
# memory usage: 504.7 KB

# %% [markdown]
# ## 5. Save Processed Data

# %%
films.to_csv("../data/processed/films_engineered.csv", index=False)

# %%
films.columns
# Out:
# Index(['id', 'title', 'year', 'country', 'runtime', 'language', 'certificate',
#        'budget', 'revenue', 'avg_rating', 'vote_count', 'target',
#        'cast_count'],
#       dtype='str')

# %%
films.isnull().sum()
# Out:
# id               0
# title            0
# year             0
# country          2
# runtime          0
# language        13
# certificate    302
# budget           0
# revenue          0
# avg_rating       0
# vote_count       0
# target           0
# cast_count       0
# dtype: int64

# %%
films["target"].value_counts(normalize=True)
# Out:
# target
# 0    0.654187
# 1    0.345813
# Name: proportion, dtype: float64

# %%
df = pd.read_csv("../data/processed/films_engineered.csv")
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4968 entries, 0 to 4967
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4968 non-null   int64
#  1   title        4968 non-null   str
#  2   year         4968 non-null   int64
#  3   country      4966 non-null   str
#  4   runtime      4968 non-null   int64
#  5   language     4955 non-null   str
#  6   certificate  4666 non-null   str
#  7   budget       4968 non-null   float64
#  8   revenue      4968 non-null   float64
#  9   avg_rating   4968 non-null   float64
#  10  vote_count   4968 non-null   int64
#  11  target       4968 non-null   int64
#  12  cast_count   4968 non-null   float64
# dtypes: float64(4), int64(5), str(4)
# memory usage: 504.7 KB
